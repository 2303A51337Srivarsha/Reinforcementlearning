# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51337Srivarsha/Reinforcementlearning/blob/main/RL_4_1337.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upper Confidence Bound

# %%
import math

machines = ['A', 'B', 'C']
N_play = 10

N = {'A': 0, 'B': 0, 'C': 0}
R = {'A': [], 'B': [], 'C': []}
Q = {'A': 0.0, 'B': 0.0, 'C': 0.0}
UCB = {'A': 0.0, 'B': 0.0, 'C': 0.0}

total_reward = 0

print("UCB Multi-Armed Bandit")

for machine in machines:
    print("\nPlay with machine", machine)
    reward = float(input("Enter reward: "))

    R[machine].append(reward)
    total_reward += reward

    N[machine] += 1

    Q[machine] = Q[machine] + (reward - Q[machine]) / N[machine]

for t in range(3, N_play):

    print("\nPlay number:", t + 1)

    for machine in machines:
        UCB[machine] = Q[machine] + math.sqrt(
            (2 * math.log(t + 1)) / N[machine]
        )

    print("UCB values:")
    for machine in machines:
        print(machine, "=", round(UCB[machine], 3))

    selected = max(UCB, key=UCB.get)

    print("Play with machine", selected)
    reward = float(input("Enter reward: "))

    R[selected].append(reward)
    total_reward += reward

    N[selected] += 1

    Q[selected] = Q[selected] + (
        reward - Q[selected]
    ) / N[selected]


for machine in machines:
    UCB[machine] = Q[machine] + math.sqrt(
        (2 * math.log(N_play)) / N[machine]
    )

print("\n--- FINAL RESULTS ---")
print("Machine\tN\tRewards\t\tUCB\tQ-value")

for machine in machines:
    print(
        machine,
        "\t",
        N[machine],
        "\t",
        R[machine],
        "\t",
        round(UCB[machine], 3),
        "\t",
        round(Q[machine], 3)
    )

print("\nTotal Reward Received =", total_reward)
# Out:
# UCB Multi-Armed Bandit
#
# Play with machine A
# Enter reward: 3
#
# Play with machine B
# Enter reward: 6
#
# Play with machine C
# Enter reward: 4
#
# Play number: 4
# UCB values:
# A = 4.665
# B = 7.665
# C = 5.665
# Play with machine B
# Enter reward: 7
#
# Play number: 5
# UCB values:
# A = 4.794
# B = 7.769
# C = 5.794
# Play with machine B
# Enter reward: 5
#
# Play number: 6
# UCB values:
# A = 4.893
# B = 7.093
# C = 5.893
# Play with machine B
# Enter reward: 8
#
# Play number: 7
# UCB values:
# A = 4.973
# B = 7.486
# C = 5.973
# Play with machine B
# Enter reward: 3
#
# Play number: 8
# UCB values:
# A = 5.039
# B = 6.712
# C = 6.039
# Play with machine B
# Enter reward: 4
#
# Play number: 9
# UCB values:
# A = 5.096
# B = 6.356
# C = 6.096
# Play with machine B
# Enter reward: 6
#
# Play number: 10
# UCB values:
# A = 5.146
# B = 6.383
# C = 6.146
# Play with machine B
# Enter reward: 5
#
# --- FINAL RESULTS ---
# Machine	N	Rewards		UCB	Q-value
# ...
