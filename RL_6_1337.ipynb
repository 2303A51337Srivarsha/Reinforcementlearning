# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51337Srivarsha/Reinforcementlearning/blob/main/RL_6_1337.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
def random_agent(environment_name, episodes=5):

    env = gym.make(environment_name)
    print("\nEnvironment:", environment_name)
    print("--------------------------------")

    episode_rewards = []
    for episode in range(1, episodes + 1):

        state, info = env.reset()
        total_reward = 0
        steps = 0

        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1

            state = next_state

        average_reward = total_reward / steps

        episode_rewards.append(total_reward)

        print("Episode", episode)
        print("Total Reward:", total_reward)
        print("Steps:", steps)
        print("Average Reward:", round(average_reward, 2))
        print()
    overall_average = sum(episode_rewards) / len(episode_rewards)

    print("Total Rewards:", episode_rewards)
    print("Overall Average Reward:", round(overall_average, 2))

    env.close()

random_agent("CliffWalking-v1", episodes=5)
random_agent("Taxi-v4", episodes=5)
# Out:
# Environment: CliffWalking-v1
# --------------------------------
# Episode 1
# Total Reward: -122363
# Steps: 12077
# Average Reward: -10.13
#
# Episode 2
# Total Reward: -10542
# Steps: 939
# Average Reward: -11.23
#
# Episode 3
# Total Reward: -103732
# Steps: 9286
# Average Reward: -11.17
#
# Episode 4
# Total Reward: -7834
# Steps: 805
# Average Reward: -9.73
#
# Episode 5
# Total Reward: -171044
# Steps: 17594
# Average Reward: -9.72
#
# Total Rewards: [-122363, -10542, -103732, -7834, -171044]
# Overall Average Reward: -83103.0
#
# Environment: Taxi-v4
# --------------------------------
# Episode 1
# Total Reward: -821
# Steps: 200
# Average Reward: -4.11
#
# Episode 2
# Total Reward: -803
# Steps: 200
# Average Reward: -4.01
#
# Episode 3
# Total Reward: -857
# Steps: 200
# Average Reward: -4.29
#
# Episode 4
# Total Reward: -652
# Steps: 196
# Average Reward: -3.33
#
# Episode 5
# Total Reward: -767
# Steps: 200
# Average Reward: -3.83
#
# ...
